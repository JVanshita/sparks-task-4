# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("D:\data analysis\globalterrorismdb_0718dist.csv", encoding='latin-1',  low_memory=False)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.nunique()
# Out:
# eventid         576
# iyear            47
# imonth           13
# iday             32
# approxdate     2244
#               ...
# INT_LOG           3
# INT_IDEO          3
# INT_MISC          3
# INT_ANY           3
# related       14306
# Length: 135, dtype: int64

# %%
#cleaning the data

# %%
data.isnull()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
renamecols = {
    'latitude':'lat',
    'longitude':'lon',
    'iyear':u'year',
    'imonth':u'month',
    'iday':u'day',
    'country_txt':u'countryt',
    'region_txt':u'region',
    'provstate':u'state',
    'attacktype1_txt':u'attacktype',
    'targtype1_txt':u'targettype',
    'weaptype1_txt':u'weaptype',
    'nkill':u'killed',
    'nwound':u'wounded',
    'gname':u'group',
}

# %%
#reading data

# %%
terror = pd.read_csv("D:\data analysis\globalterrorismdb_0718dist.csv", encoding='latin-1', low_memory=False) 
terror.rename(columns=renamecols,inplace=True)
terror= terror.apply(lambda x:x.encode('utf-8').strip() if isinstance(x, str) else x)

# %%
terror = terror[['year', 'lat', 'lon', 'month', 'day', 'countryt', 'region', 'state', 'attacktype', 'targettype', 'weaptype', 'killed', 'wounded', 'group', 'motive', 'summary', 'city']]

# %%
terror.shape
# Out:
# (181691, 18)

# %%
terror.head()
# Out:
#    year        lat         lon  month  day            countryt region  \
# 0  1970  18.456792  -69.951164      7    2  Dominican Republic      2
# 1  1970  19.371887  -99.086624      0    0              Mexico      1
# 2  1970  15.478598  120.599741      1    0         Philippines      5
# 3  1970  37.997490   23.762728      1    0              Greece      8
# 4  1970  33.580412  130.396361      1    0               Japan      4
#
#                         region    state                      attacktype  \
# 0  Central America & Caribbean      NaN                   Assassination
# 1                North America  Federal     Hostage Taking (Kidnapping)
# 2               Southeast Asia   Tarlac                   Assassination
# 3               Western Europe   Attica               Bombing/Explosion
# 4                    East Asia  Fukouka  Facility/Infrastructure Attack
#
#                     targettype    weaptype  killed  wounded  \
# ...

# %%
terror.tail()
# Out:
#         year        lat         lon  month  day     countryt region  \
# 181686  2017   2.359673   45.385034     12   31      Somalia     11
# 181687  2017  35.407278   35.942679     12   31        Syria     10
# 181688  2017   6.900742  124.437908     12   31  Philippines      5
# 181689  2017  24.798346   93.940430     12   31        India      6
# 181690  2017   7.209594  124.241966     12   31  Philippines      5
#
#                             region            state  \
# 181686          Sub-Saharan Africa  Middle Shebelle
# 181687  Middle East & North Africa         Lattakia
# 181688              Southeast Asia      Maguindanao
# 181689                  South Asia          Manipur
# 181690              Southeast Asia      Maguindanao
#
#                             attacktype                   targettype  \
# 181686                   Armed Assault                     Military
# 181687               Bombing/Explosion                     Military
# ...

# %%
terror.isnull().sum()
# Out:
# year               0
# lat             4556
# lon             4557
# month              0
# day                0
# countryt           0
# region             0
# region             0
# state            421
# attacktype         0
# targettype         0
# weaptype           0
# killed         10313
# wounded        16311
# group              0
# motive        131130
# summary        66129
# city             434
# dtype: int64

# %%
terror.isnull()
# Out:
#          year    lat    lon  month    day  countryt  region  region  state  \
# 0       False  False  False  False  False     False   False   False   True
# 1       False  False  False  False  False     False   False   False  False
# 2       False  False  False  False  False     False   False   False  False
# 3       False  False  False  False  False     False   False   False  False
# 4       False  False  False  False  False     False   False   False  False
# ...       ...    ...    ...    ...    ...       ...     ...     ...    ...
# 181686  False  False  False  False  False     False   False   False  False
# 181687  False  False  False  False  False     False   False   False  False
# 181688  False  False  False  False  False     False   False   False  False
# 181689  False  False  False  False  False     False   False   False  False
# 181690  False  False  False  False  False     False   False   False  False
#
# ...

# %%
#removing unknown values in coordinates

# %%
terror = terror[pd.notnull(terror.lat)]
terror = terror[pd.notnull(terror.lon)]
print("unknown values of latitude and longitude are removed")
# Out:
# unknown values of latitude and longitude are removed

# %%
exclude_cols=['year','lat','lon']
float_cols = [c for c in terror.select_dtypes(include=[float]).columns.tolist() if c not in exclude_cols]

# %%
terror[float_cols]= terror[float_cols].fillna(0).astype(int)

# %%
terror[float_cols]= terror[float_cols].mask(terror[float_cols]<0,0)

# %%
terror['wounded'] = terror['wounded'].fillna(0)
terror['killed'] = terror['killed'].fillna(0)

# %%
terror['casualties']= terror['killed']+terror['wounded']

# %%
terror['city']= terror['city'].replace(['unknown'],'bagdad')

# %%
terror
# Out:
#         year        lat         lon  month  day            countryt region  \
# 0       1970  18.456792  -69.951164      7    2  Dominican Republic      2
# 1       1970  19.371887  -99.086624      0    0              Mexico      1
# 2       1970  15.478598  120.599741      1    0         Philippines      5
# 3       1970  37.997490   23.762728      1    0              Greece      8
# 4       1970  33.580412  130.396361      1    0               Japan      4
# ...      ...        ...         ...    ...  ...                 ...    ...
# 181686  2017   2.359673   45.385034     12   31             Somalia     11
# 181687  2017  35.407278   35.942679     12   31               Syria     10
# 181688  2017   6.900742  124.437908     12   31         Philippines      5
# 181689  2017  24.798346   93.940430     12   31               India      6
# 181690  2017   7.209594  124.241966     12   31         Philippines      5
#
#                              region            state  \
# ...

# %%
Year = terror['year'].unique()
years_count = terror['year'].value_counts(dropna=False).sort_index()

plt.figure(figsize=(18, 10))
sns.barplot(x=Year, y=years_count, palette="tab10")
plt.xticks(rotation=50)
plt.xlabel('Attacking Year', fontsize=20)
plt.ylabel('Number of Attacks Each Year', fontsize=20)
plt.title('Attacks in Year', fontsize=30)
plt.show()

# %%
#conclusions from the graph is that maximum attacks happenend in 2014

# %%
attacks = terror["year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index": "year", "year": "attacks"}).set_index("year")
attacks.head()
# Out:
#       attacks
# year
# 1970      643
# 1971      463
# 1972      551
# 1973      465
# 1974      577

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("timeline of Attacks", fontsize=15)
plt.xlabel("years",fontsize=15)
plt.ylabel("Number of Attacks", fontsize=15)
plt.show()

# %%
#most number of attacks were in 2014 which is 16903
#least number of Attacks were in 1971 which is 471

# %%
#2.Total casualties{killed +Wounded}in each year

# %%
yc=terror[["year","casualties"]].groupby("year").sum()
yc.head()
# Out:
#       casualties
# year
# 1970         348
# 1971         254
# 1972         949
# 1973         863
# 1974        1402

# %%
yc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Year wise Casualties", fontsize=15)
plt.xlabel("years",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties", fontsize=15)
plt.show()

# %%
yk=terror[["year","killed"]].groupby("year").sum()
yk.head()
# Out:
#       killed
# year
# 1970     136
# 1971     172
# 1972     540
# 1973     368
# 1974     537

# %%
yw=terror[["year","wounded"]].groupby("year").sum()
yw.head()
# Out:
#       wounded
# year
# 1970      212
# 1971       82
# 1972      409
# 1973      495
# 1974      865

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#killed
yk.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("people killed in each year")
ax0.set_xlabel("year")
ax0.set_ylabel("no of people killed")

#wounded
yk.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("people wounded in each year")
ax1.set_xlabel("year")
ax1.set_ylabel("no of people wounded")

plt.show()

# %%
#REGION WISE ATTACKS

# %%
# 1. Distribution of terrorist attacks over regions from 1970-2017

# %%
chunk_size = 10000  # You can increase or decrease this based on available memory

# Initialize an empty DataFrame to store the crosstab results
final_crosstab = None

# Create an iterator to read the CSV file in chunks
csv_iterator = pd.read_csv("D:\data analysis\globalterrorismdb_0718dist.csv", encoding='latin-1', chunksize=chunk_size)

# Iterate over chunks and aggregate data
for chunk in csv_iterator:
    # Assuming your dataset has 'year' and 'region' columns
    crosstab_chunk = pd.crosstab(chunk['iyear'], chunk['region_txt'])
    
    # Combine the chunk's crosstab with the final result
    if final_crosstab is None:
        final_crosstab = crosstab_chunk
    else:
        final_crosstab = final_crosstab.add(crosstab_chunk, fill_value=0)

# Now you have the final crosstabulation in 'final_crosstab' variable
final_crosstab.head()
# Out:
# region_txt  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# iyear
# 1970                          1.0                          7.0           NaN
# 1971                          1.0                          5.0           NaN
# 1972                          8.0                          3.0           NaN
# 1973                          1.0                          6.0           NaN
# 1974                          1.0                         11.0           NaN
#
# region_txt  East Asia  Eastern Europe  Middle East & North Africa  \
# iyear
# 1970              2.0            12.0                        28.0
# 1971              1.0             5.0                        55.0
# 1972              0.0             1.0                        53.0
# 1973              2.0             1.0                        19.0
# 1974              4.0             2.0                        42.0
#
# region_txt  North America  South America  South Asia  Southeast Asia  \
# iyear
# ...

# %%
final_crosstab.plot(kind="area",stacked=False, alpha=0.5 ,figsize=(20,10))
plt.title("Region wise Attacks", fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks", fontsize=15)
plt.show()

# %%
regt=final_crosstab.transpose()
regt["total"]=regt.sum(axis=1)
ra=regt["total"].sort_values(ascending=False)
ra
# Out:
# region_txt
# Middle East & North Africa     50474.0
# South Asia                     44974.0
# South America                  18978.0
# Sub-Saharan Africa             17550.0
# Western Europe                 16639.0
# Southeast Asia                 12485.0
# Central America & Caribbean    10344.0
# Eastern Europe                  5144.0
# North America                   3456.0
# East Asia                        802.0
# Central Asia                     563.0
# Australasia & Oceania            282.0
# Name: total, dtype: float64

# %%
ra.plot(kind="bar", figsize=(15,6))
plt.title("Total Number Of Attacks In each Region from 1970-2017", fontsize=15)
plt.xlabel("Regions",fontsize=15)
plt.ylabel("Number of Attacks", fontsize=15)
plt.show()

# %%
# based on countries

# %%
ct=terror["countryt"].value_counts().head(10)
ct
# Out:
# Iraq              24487
# Pakistan          14318
# Afghanistan       12639
# India             11801
# Colombia           7835
# Philippines        6528
# Peru               5808
# United Kingdom     5227
# El Salvador        4846
# Turkey             4126
# Name: countryt, dtype: int64

# %%
ct.plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("country wise attacks", fontsize=15)
plt.xlabel("years",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of attacks", fontsize=15)
plt.show()

# %%
cnc=terror[["countryt","casualties"]].groupby("countryt").sum().sort_values(by="casualties",ascending=False)
cnc.head(10)
# Out:
#                casualties
# countryt
# Iraq               212410
# Afghanistan         83471
# Pakistan            65527
# India               47248
# Nigeria             32873
# Sri Lanka           30238
# Syria               29117
# United States       24473
# Colombia            23620
# Philippines         20160

# %%
cnc[:10].plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("country wise casualties", fontsize=15)
plt.xlabel("countries",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of casualties", fontsize=15)
plt.show()

# %%
cnk=terror[["countryt","killed"]].groupby("countryt").sum().sort_values(by="killed",ascending=False)
cnc.head(10)
# Out:
#                casualties
# countryt
# Iraq               212410
# Afghanistan         83471
# Pakistan            65527
# India               47248
# Nigeria             32873
# Sri Lanka           30238
# Syria               29117
# United States       24473
# Colombia            23620
# Philippines         20160

# %%
cnw=terror[["countryt","wounded"]].groupby("countryt").sum().sort_values(by="wounded",ascending=False)
cnw.head(10)
# Out:
#                wounded
# countryt
# Iraq            134235
# Afghanistan      44224
# Pakistan         41848
# India            28585
# United States    20702
# Sri Lanka        15271
# Syria            13998
# Philippines      12191
# Lebanon          10490
# Nigeria          10214

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#killed
cnk[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("people killed in each country")
ax0.set_xlabel("country")
ax0.set_ylabel("no of people killed")

#wounded
cnw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("people wounded in each country")
ax1.set_xlabel("country")
ax1.set_ylabel("no of people wounded")

plt.show()

# %%
#city wise attacks-top10

# %%
city=terror["city"].value_counts()[1:11]
city
# Out:
# Unknown         7534
# Karachi         2651
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1580
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: city, dtype: int64

# %%
city.plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("city wise attacks", fontsize=15)
plt.xlabel("Cities",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of attacks", fontsize=15)
plt.show()

# %%
 #the unknown city is Baghdad

# %%
cc=terror[["city","casualties"]].groupby("city").sum().sort_values(by="casualties",ascending=False)
cnc.head(10)
# Out:
#                casualties
# countryt
# Iraq               212410
# Afghanistan         83471
# Pakistan            65527
# India               47248
# Nigeria             32873
# Sri Lanka           30238
# Syria               29117
# United States       24473
# Colombia            23620
# Philippines         20160

# %%
cc[:10].plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("city wise casualties", fontsize=15)
plt.xlabel("city",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of casualties", fontsize=15)
plt.show()

# %%
ck=terror[["city","killed"]].groupby("city").sum().sort_values(by="killed",ascending=False)
ck.head(10)
# Out:
#                killed
# city
# Baghdad         21151
# Unknown         17035
# Mosul            7140
# Mogadishu        3913
# Karachi          3669
# New York City    2838
# Tikrit           2679
# Kabul            2491
# Ramadi           2313
# Maiduguri        2235

# %%
cw=terror[["city","wounded"]].groupby("city").sum().sort_values(by="wounded",ascending=False)
cw.head(10)
# Out:
#                wounded
# city
# Baghdad          56725
# New York City    16781
# Unknown           9525
# Kabul             5969
# Mosul             5787
# Karachi           5688
# Tokyo             5542
# Beirut            5341
# Nairobi           5024
# Kirkuk            5008

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#killed
ck[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("people killed in each city")
ax0.set_xlabel("city")
ax0.set_ylabel("no of people killed")

#wounded
cw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("people wounded in each city")
ax1.set_xlabel("city")
ax1.set_ylabel("no of people wounded")

plt.show()

# %%
# Terrorist Group Wise Attacks- Top 10

# %%
grp= terror["group"].value_counts()[1:10]
grp
# Out:
# Taliban                                             7457
# Islamic State of Iraq and the Levant (ISIL)         5584
# Shining Path (SL)                                   4306
# Al-Shabaab                                          3274
# Farabundo Marti National Liberation Front (FMLN)    2991
# Irish Republican Army (IRA)                         2662
# New People's Army (NPA)                             2502
# Boko Haram                                          2408
# Revolutionary Armed Forces of Colombia (FARC)       2332
# Name: group, dtype: int64

# %%
grp.plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("group wise attacks", fontsize=15)
plt.xlabel("group",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of attacks", fontsize=15)
plt.show()

# %%
gc=terror[["group","casualties"]].groupby("group").sum().sort_values(by="casualties",ascending=False)
gc.head(10)
# Out:
#                                              casualties
# group
# Unknown                                          317339
# Islamic State of Iraq and the Levant (ISIL)       69380
# Taliban                                           57300
# Boko Haram                                        29743
# Al-Qaida                                          28372
# Liberation Tigers of Tamil Eelam (LTTE)           21609
# Al-Shabaab                                        16928
# Tehrik-i-Taliban Pakistan (TTP)                   15551
# Al-Qaida in Iraq                                  14688
# Shining Path (SL)                                 13008

# %%
gc.head(10).plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("group wise casualties", fontsize=15)
plt.xlabel("group",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of casualties", fontsize=15)
plt.show()

# %%
gk=terror[["group","killed"]].groupby("group").sum().sort_values(by="killed",ascending=False)
gk.head(10)
# Out:
#                                                   killed
# group
# Unknown                                           109616
# Islamic State of Iraq and the Levant (ISIL)        38775
# Taliban                                            29382
# Boko Haram                                         20290
# Liberation Tigers of Tamil Eelam (LTTE)            10733
# Shining Path (SL)                                  10174
# Al-Shabaab                                          9320
# Farabundo Marti National Liberation Front (FMLN)    7584
# Tehrik-i-Taliban Pakistan (TTP)                     6019
# Revolutionary Armed Forces of Colombia (FARC)       5036

# %%
gw=terror[["group","wounded"]].groupby("group").sum().sort_values(by="wounded",ascending=False)
gw.head(10)
# Out:
#                                              wounded
# group
# Unknown                                       207723
# Islamic State of Iraq and the Levant (ISIL)    30605
# Taliban                                        27918
# Al-Qaida                                       24512
# Liberation Tigers of Tamil Eelam (LTTE)        10876
# Al-Qaida in Iraq                               10320
# Tehrik-i-Taliban Pakistan (TTP)                 9532
# Boko Haram                                      9453
# Al-Shabaab                                      7608
# Aum Shinri Kyo                                  6003

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#killed
gk[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("people killed by each group")
ax0.set_xlabel("group")
ax0.set_ylabel("no of people killed")

#wounded
gw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("people wounded by each group")
ax1.set_xlabel("group")
ax1.set_ylabel("no of people wounded")

plt.show()

# %%
# Attack type wise Attacks

# %%
at=terror["attacktype"].value_counts()
at
# Out:
# Bombing/Explosion                      86843
# Armed Assault                          41107
# Assassination                          18819
# Hostage Taking (Kidnapping)            10671
# Facility/Infrastructure Attack         10186
# Unknown                                 6931
# Unarmed Assault                          986
# Hostage Taking (Barricade Incident)      962
# Hijacking                                629
# Name: attacktype, dtype: int64

# %%
at.plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("types of attacks", fontsize=15)
plt.xlabel("Attack types",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of attacks", fontsize=15)
plt.show()

# %%
ac=terror[["attacktype","casualties"]].groupby("attacktype").sum().sort_values(by="casualties",ascending=False)
ac.head(10)
# Out:
#                                      casualties
# attacktype
# Bombing/Explosion                        524373
# Armed Assault                            223923
# Unknown                                   44176
# Assassination                             37742
# Hostage Taking (Kidnapping)               29976
# Hijacking                                 20681
# Unarmed Assault                           14675
# Hostage Taking (Barricade Incident)        8416
# Facility/Infrastructure Attack             7184

# %%
ac.plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("attack wise casualties", fontsize=15)
plt.xlabel("Attack types",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of casualties", fontsize=15)
plt.show()

# %%
ak=terror[["attacktype","killed"]].groupby("attacktype").sum().sort_values(by="killed",ascending=False)
ak.head(10)
# Out:
#                                      killed
# attacktype
# Bombing/Explosion                    155101
# Armed Assault                        149627
# Unknown                               30291
# Assassination                         24004
# Hostage Taking (Kidnapping)           23640
# Hostage Taking (Barricade Incident)    4461
# Hijacking                              3692
# Facility/Infrastructure Attack         3587
# Unarmed Assault                         821

# %%
aw=terror[["attacktype","wounded"]].groupby("attacktype").sum().sort_values(by="wounded",ascending=False)
aw.head(10)
# Out:
#                                      wounded
# attacktype
# Bombing/Explosion                     369272
# Armed Assault                          74296
# Hijacking                              16989
# Unknown                                13885
# Unarmed Assault                        13854
# Assassination                          13738
# Hostage Taking (Kidnapping)             6336
# Hostage Taking (Barricade Incident)     3955
# Facility/Infrastructure Attack          3597

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#killed
ak[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("people killed by each type of attack")
ax0.set_xlabel("attack types")
ax0.set_ylabel("no of people killed")

#wounded
aw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("people wounded by each type of attack")
ax1.set_xlabel("type of attack")
ax1.set_ylabel("no of people wounded")

plt.show()

# %%
# target type wise attacks

# %%
ta=terror["targettype"].value_counts()
ta
# Out:
# Private Citizens & Property       42568
# Military                          26893
# Police                            24140
# Government (General)              20809
# Business                          20274
# Transportation                     6550
# Unknown                            5831
# Utilities                          5552
# Religious Figures/Institutions     4382
# Educational Institution            4269
# Government (Diplomatic)            3515
# Terrorists/Non-State Militia       2972
# Journalists & Media                2855
# Violent Political Party            1839
# Airports & Aircraft                1310
# Telecommunication                   996
# NGO                                 942
# Tourists                            422
# Maritime                            314
# Food or Water Supply                301
# Abortion Related                    263
# Other                               137
# Name: targettype, dtype: int64

# %%
ta.plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("types of targets", fontsize=15)
plt.xlabel("target types",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of attacks", fontsize=15)
plt.show()

# %%
tc=terror[["targettype","casualties"]].groupby("targettype").sum().sort_values(by="casualties",ascending=False)
tc.head(10)
# Out:
#                                 casualties
# targettype
# Private Citizens & Property         311795
# Military                            168388
# Police                              116852
# Business                             76798
# Government (General)                 66017
# Transportation                       52998
# Religious Figures/Institutions       37259
# Terrorists/Non-State Militia         16910
# Educational Institution              13851
# Government (Diplomatic)              13313

# %%
tc.plot(kind="bar",color= "cornflowerblue", figsize=(15,6))
plt.title("target type wise casualties", fontsize=15)
plt.xlabel("target types",fontsize=15)
plt.xticks(fontsize=12)
plt.ylabel("Number of casualties", fontsize=15)
plt.show()

# %%
tk=terror[["targettype","killed"]].groupby("targettype").sum().sort_values(by="killed",ascending=False)
tk.head(10)
# Out:
#                                 killed
# targettype
# Private Citizens & Property     135154
# Military                         99479
# Police                           52769
# Government (General)             25154
# Business                         22887
# Transportation                   13203
# Religious Figures/Institutions   13115
# Terrorists/Non-State Militia      8804
# Unknown                           4249
# Educational Institution           3688

# %%
tw=terror[["targettype","wounded"]].groupby("targettype").sum().sort_values(by="wounded",ascending=False)
tw.head(10)
# Out:
#                                 wounded
# targettype
# Private Citizens & Property      176641
# Military                          68909
# Police                            64083
# Business                          53911
# Government (General)              40863
# Transportation                    39795
# Religious Figures/Institutions    24144
# Government (Diplomatic)           10312
# Educational Institution           10163
# Terrorists/Non-State Militia       8106

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#killed
tk.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("people killed by each type of target")
ax0.set_xlabel("target types")
ax0.set_ylabel("no of people killed")

#wounded
tw.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("people wounded by each type of target")
ax1.set_xlabel("type of target")
ax1.set_ylabel("no of people wounded")

plt.show()

# %%
casualty=terror.loc[:"casualties"].sum()
print(casualty)
# Out:
# year                                                  354784018
# lat                                              4162373.313426
# lon                                            -81250595.802902
# month                                                   1145821
# day                                                     2748761
# countryt      Dominican RepublicMexicoPhilippinesGreeceJapan...
# region                                                  1274196
# region        Central America & CaribbeanNorth AmericaSouthe...
# attacktype    AssassinationHostage Taking (Kidnapping)Assass...
# targettype    Private Citizens & PropertyGovernment (Diploma...
# weaptype      UnknownUnknownUnknownExplosivesIncendiaryFirea...
# killed                                                   395224
# wounded                                                  515922
# group         MANO-D23rd of September Communist LeagueUnknow...
# casualties                                               911146
# ...

# %%
#Observation & Conclusions.

# Country with the highest number of Terrorist Attacks: Iraq
# Regions with the highest number of Terrorist Attacks: Middle East & North Africa
# Most number of deaths by a single attack is 1570 people that took place in Iraq
# City with the most attacks Baghdad
# Year with the most attacks 2014
# Month with the most attacks: 5
# Group with the most attacks Taliban
# Most Attack Types: Bombing/Explosion
# Number of people killed by terror attack: 411868
# Terrorist attacks have increased in recent years.
# Armed assault and bombing/explosion are seen to be the cause of 77% of the deaths in these attacks
